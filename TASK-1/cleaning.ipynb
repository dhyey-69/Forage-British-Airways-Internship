# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/Internship/Sem-5/TASK-1/BA_reviews.csv')
print(data)
# Out:
#                                                 reviews  \
# 0     ✅ Trip Verified |  As always when I fly BA it ...
# 1     ✅ Trip Verified |  First time using BA busines...
# 2     Not Verified |  Extremely rude ground service....
# 3     ✅ Trip Verified |  My son and I flew to Geneva...
# 4     ✅ Trip Verified |  For the price paid (bought ...
# ...                                                 ...
# 3413  Travelled from SYD to London return. Poor serv...
# 3414  VIE to LHR - Seats were of the new configurati...
# 3415  NCL-LHR-LAX / LAS-LHR-NCL. NCL-LHR A320. Comfo...
# 3416  Traveled to Rome with British Airways. On the ...
# 3417  BA26 22/6/2014. During my trip to the UK I fee...
#
#                               stars                date         country
# 0     \n\t\t\t\t\t\t\t\t\t\t\t\t\t5    9th January 2024           Spain
# 1                                 1    7th January 2024  United Kingdom
# 2                                 9    3rd January 2024   United States
# 3                                 6    2nd January 2024           China
# 4                                 1  29th December 2023  United Kingdom
# ...                             ...                 ...             ...
# 3413                              8    8th October 2014       Australia
# 3414                              6    8th October 2014  United Kingdom
# 3415                              3    5th October 2014  United Kingdom
# 3416                              3    5th October 2014  United Kingdom
# 3417                              1    5th October 2014       Hong Kong
#
# [3418 rows x 4 columns]

# %%
data.head()
# Out:
#                                              reviews  \
# 0  ✅ Trip Verified |  As always when I fly BA it ...
# 1  ✅ Trip Verified |  First time using BA busines...
# 2  Not Verified |  Extremely rude ground service....
# 3  ✅ Trip Verified |  My son and I flew to Geneva...
# 4  ✅ Trip Verified |  For the price paid (bought ...
#
#                            stars                date         country
# 0  \n\t\t\t\t\t\t\t\t\t\t\t\t\t5    9th January 2024           Spain
# 1                              1    7th January 2024  United Kingdom
# 2                              9    3rd January 2024   United States
# 3                              6    2nd January 2024           China
# 4                              1  29th December 2023  United Kingdom

# %%
data['verified'] = data.reviews.str.contains("Trip Verified")
data['verified']
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 3413    False
# 3414    False
# 3415    False
# 3416    False
# 3417    False
# Name: verified, Length: 3418, dtype: bool

# %%
#for lemmatization(reducing words to their base or root form) of words we will use nltk library
from nltk.stem import WordNetLemmatizer
import nltk
from nltk.corpus import stopwords
import re
lemma = WordNetLemmatizer()


reviews_data = data.reviews.str.strip("✅ Trip Verified |")

#create an empty list to collect cleaned data corpus
corpus =[]

#loop through each review, remove punctuations, small case it, join it and add it to corpus
for rev in reviews_data:
    rev = re.sub('[^a-zA-Z]',' ', rev)
    rev = rev.lower()
    rev = rev.split()
    rev = [lemma.lemmatize(word) for word in rev if word not in set(stopwords.words("english"))]
    rev = " ".join(rev)
    corpus.append(rev)

# %%
data['corpus'] = corpus

# %%
from textblob import TextBlob

sentiment=[]

reviews_data = data.reviews.str.strip("✅ Trip Verified |")
def get_sentiment(text):
    analysis = TextBlob(text)
    # Sentiment polarity is a float within the range [-1.0, 1.0]
    # -1.0 is very negative, 1.0 is very positive
    sentiment_polarity = analysis.sentiment.polarity

    if sentiment_polarity > 0:
        return "Positive"
    elif sentiment_polarity < 0:
        return "Negative"
    else:
        return "Neutral"

for i in reviews_data:
  i = get_sentiment(i)
  sentiment.append(i)

# %%
data['sentiment'] = sentiment

# %%
data.dtypes
# Out:
# reviews      object
# stars        object
# date         object
# country      object
# verified       bool
# sentiment    object
# dtype: object

# %%
data.date = pd.to_datetime(data.date)
data.dtypes
# Out:
# reviews              object
# stars                object
# date         datetime64[ns]
# country              object
# verified               bool
# sentiment            object
# dtype: object

# %%
data.stars.unique()
# Out:
# array(['\n\t\t\t\t\t\t\t\t\t\t\t\t\t5', '1', '9', '6', '8', '2', '5', '3',
#        '10', '4', '7', 'None'], dtype=object)

# %%
data.stars = data.stars.str.strip("\n\t\t\t\t\t\t\t\t\t\t\t\t\t")

# %%
data.stars.value_counts()
# Out:
# 1       826
# 2       395
# 3       389
# 8       332
# 10      281
# 9       272
# 7       271
# 5       244
# 4       234
# 6       171
# None      3
# Name: stars, dtype: int64

# %%
data.drop(data[data.stars == "None"].index, axis=0, inplace=True)
data.stars.unique()
# Out:
# array(['5', '1', '9', '6', '8', '2', '3', '10', '4', '7'], dtype=object)

# %%
data.isnull().value_counts()
# Out:
# reviews  stars  date   country  verified  sentiment
# False    False  False  False    False     False        3413
#                        True     False     False           2
# dtype: int64

# %%
data.country.isnull().value_counts()
# Out:
# False    3413
# True        2
# Name: country, dtype: int64

# %%
data.drop(data[data.country.isnull() == True].index,
          axis = 0,inplace=True)

# %%
data.shape
# Out:
# (3413, 6)

# %%
data.reset_index(drop=True)
# Out:
#                                                 reviews stars       date  \
# 0     ✅ Trip Verified |  As always when I fly BA it ...     5 2024-01-09
# 1     ✅ Trip Verified |  First time using BA busines...     1 2024-01-07
# 2     Not Verified |  Extremely rude ground service....     9 2024-01-03
# 3     ✅ Trip Verified |  My son and I flew to Geneva...     6 2024-01-02
# 4     ✅ Trip Verified |  For the price paid (bought ...     1 2023-12-29
# ...                                                 ...   ...        ...
# 3408  Travelled from SYD to London return. Poor serv...     8 2014-10-08
# 3409  VIE to LHR - Seats were of the new configurati...     6 2014-10-08
# 3410  NCL-LHR-LAX / LAS-LHR-NCL. NCL-LHR A320. Comfo...     3 2014-10-05
# 3411  Traveled to Rome with British Airways. On the ...     3 2014-10-05
# 3412  BA26 22/6/2014. During my trip to the UK I fee...     1 2014-10-05
#
#              country  verified sentiment
# 0              Spain      True  Positive
# 1     United Kingdom      True  Positive
# 2      United States     False  Negative
# 3              China      True  Negative
# 4     United Kingdom      True  Positive
# ...              ...       ...       ...
# 3408       Australia     False  Negative
# 3409  United Kingdom     False  Positive
# 3410  United Kingdom     False  Positive
# 3411  United Kingdom     False  Positive
# 3412       Hong Kong     False  Positive
#
# [3413 rows x 6 columns]

# %%
data.to_csv('/content/drive/MyDrive/Internship/Sem-5/TASK-1/cleaned_data.csv',index=False)
